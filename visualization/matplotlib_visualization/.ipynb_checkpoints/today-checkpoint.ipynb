# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(1,50)
Y = X**2

# %%
fig, aux = plt.subplots()
aux.plot(X,Y)
aux.set_xlabel("X axis")
aux.set_ylabel("Y axis")
aux.set_title("Relationship b/w variables X and Y")
plt.show()
